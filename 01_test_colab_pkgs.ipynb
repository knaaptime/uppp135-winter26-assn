# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/uppp_214/python_packages')

# %%
import geodatasets
import geopandas as gpd
atl = gpd.read_file(geodatasets.get_path('geoda atlanta'))
atl.explore()

# %%
from lonboard import viz
from geosnap import DataStore, io as gio

# %%
data_dir = '/content/drive/MyDrive/uppp_214/data/geosnap'
datasets = DataStore(data_dir)

dc = gio.get_acs(datasets, state_fips='11', years=2021)
viz(dc)

# %%
schools = gio.get_nces(datasets, dataset='schools', years='1516')
schools = schools[schools['LSTATE'] == 'CA']
viz(schools)

# %%
ej = gio.get_ejscreen(datasets, year=2021, county_fips='06037')
viz(ej)
